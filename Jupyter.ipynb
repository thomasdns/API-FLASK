# %% [markdown]
# # Mon 1er Notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/thoma/OneDrive/Documents/GitHub/API-FLASK/dataset.csv")

# %%
data.head()
# Out:
#    FacilityID                                  URL                  Name  \
# 0           1  https://toiletmap.gov.au/facility/1   Sandy Beach Reserve
# 1           2  https://toiletmap.gov.au/facility/2         Point Reserve
# 2           3  https://toiletmap.gov.au/facility/3  Success Hill Reserve
# 3           4  https://toiletmap.gov.au/facility/4       Jubilee Reserve
# 4           5  https://toiletmap.gov.au/facility/5      Ashfield Reserve
#
#       FacilityType                    Address1        Town State AddressNote  \
# 0  Park or reserve       Lost 15525, West Road  Bassendean    WA         NaN
# 1  Park or reserve         Lot 197, North Road  Bassendean    WA         NaN
# 2  Park or reserve    Lot 2838, Seventh Avenue  Bassendean    WA         NaN
# 3  Park or reserve     Lot 6322, Robinson Road   Eden Hill    WA         NaN
# 4  Park or reserve  Lot 12061, 2 Coulston Road    Ashfield    WA         NaN
#
# ...

# %%
data["FacilityType"]
# Out:
# 0        Park or reserve
# 1        Park or reserve
# 2        Park or reserve
# 3        Park or reserve
# 4        Park or reserve
#               ...
# 23658    Park or reserve
# 23659          Rest area
# 23660    Shopping centre
# 23661    Shopping centre
# 23662    Shopping centre
# Name: FacilityType, Length: 23663, dtype: object

# %%
data_viz = data["FacilityType"].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
data_viz.plot(kind="bar")
plt.title("Toilettes-Australie")
plt.xlabel('Lieux')
plt.ylabel('Nombre de toilettes')
# Out:
# Text(0, 0.5, 'Nombre de toilettes')

# %%
plt.figure(figsize=(10,10))
plt.title("title")
plt.pie(data_viz, labels=data_viz.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x285c9565ac0>,
# ...
#  [Text(0.3542200461002029, 1.0414068172144688, 'Park or reserve'),
#   Text(-1.0855079596054324, 0.17796760838211875, 'Other'),
#   Text(-0.8785043858447746, -0.661989459169476, 'Service station'),
#   Text(-0.372277722411285, -1.0350890287295418, 'Sporting facility'),
#   Text(0.11058452523397021, -1.094427276148935, 'Shopping centre'),
#   Text(0.41563350018818557, -1.018454119497446, 'Community building'),
#   Text(0.6120604774888677, -0.9139923259503329, 'Car park'),
#   Text(0.7658255077869043, -0.7896273118521994, 'Camping ground'),
#   Text(0.8842713056544433, -0.6542661981152519, 'Train station'),
#   Text(0.9733535254284325, -0.5124284482111061, 'Rest area'),
#   Text(1.0322169565613704, -0.38016858705998074, 'Beach'),
#   Text(1.0689807442134043, -0.2593842101997661, 'Food outlet'),
#   Text(1.0855787621406354, -0.17753521112502077, 'Caravan park'),
#   Text(1.091981801915585, -0.13257354293067827, 'Cemetery'),
# ...

# %%
data_viz2 = data["State"].value_counts()
plt.figure(figsize=(10,10))
plt.title("title")
plt.pie(data_viz2, labels=data_viz2.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x285c97fc860>,
# ...
#  [Text(0.6002007732693039, 0.9218237530932525, 'NSW'),
#   Text(-1.0086615793696596, 0.4388642367560885, 'VIC'),
#   Text(-0.6667855673813549, -0.8748697086606237, 'QLD'),
#   Text(0.31493429665380257, -1.053952745046558, 'WA'),
#   Text(0.8689037334708126, -0.6745415494693289, 'SA'),
#   Text(1.060093407962281, -0.29360171388279893, 'TAS'),
#   Text(1.0943309712525269, -0.11153351674497462, 'NT'),
#   Text(1.0995350396462489, -0.031979627735825585, 'ACT')])

# %%
long = data["Longitude"]
lat = data["Latitude"]

# %%
plt.figure(figsize=(20,20))
plt.title("Map")
plt.scatter(long,lat)

# %%
for index,row in data.iterrows():
    print(row["Town"])
# Out:
# Bassendean
# Bassendean
# Bassendean
# Eden Hill
# Ashfield
# Bassendean
# Eden Hill
# Bassendean
# Moranbah
# Moranbah
# Moranbah
# Moranbah
# Moranbah
# Clermont
# Clermont
# Clermont
# Clermont
# Clermont
# East Palmerston
# Innisfail
# Innisfail
# Innisfail
# Innisfail
# Coconuts
# Flying Fish Point
# East Innisfail
# East Innisfail
# Mourilyan Harbour
# South Johnstone
# Germantown
# Japoonvale
# Kurrimine Beach
# Cowley Beach
# El Arish
# El Arish
# Mission Beach
# Mission Beach
# Bingil Bay
# Bingil Bay
# Mission Beach
# Mourilyan Harbour
# Mighell
# Walliston
# Pickering Brook
# Kalamunda
# High Wycombe
# Gooseberry Hill
# Kalamunda
# Kalamunda
# Lesmurdie
# Maida Vale
# Kalamunda
# Lesmurdie
# Kalamunda
# East Fremantle
# East Fremantle
# Exmouth
# Exmouth
# North West Cape
# North West Cape
# Thargomindah
# Thargomindah
# Thargomindah
# Hungerford
# Millmerran
# Millmerran
# Millmerran
# Millmerran
# Pampas
# Cecil Plains
# Beaudesert
# Beaudesert
# Beaudesert
# Darlington
# ...

# %%
import folium

# %%
from folium.plugins import MarkerCluster

# %%
carte = folium.Map(location=[data["Latitude"].mean(),data['Longitude'].mean()],zoom_start=4)
clusters = MarkerCluster().add_to(carte)
for index,row in data.iterrows():
    folium.Marker(location=[row["Latitude"],row["Longitude"]]).add_to(clusters)

# %%
carte.save("./carte.html")
